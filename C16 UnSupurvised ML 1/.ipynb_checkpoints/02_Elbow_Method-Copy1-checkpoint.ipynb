# %%
import seaborn as sns
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    random_state=42
)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],c=y)
# Out:
# <Axes: >

# %%
# K - Means Clustering :

from sklearn.cluster import KMeans

# For this using the known k value :
K = 4

km = KMeans(n_clusters=K,random_state=42)

y_predict = km.fit_predict(X)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],c=y_predict)
# Out:
# <Axes: >

# %%
# Elbow Method :

wcss = []

for k in range(1,21):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit_predict(X)
    wcss.append(km.inertia_)

# %%
sns.lineplot(x=range(1,21), y=wcss,marker='o')
# Out:
# <Axes: >

# %%
# Kneed Module :

# !pip install kneed
# Out:
# Requirement already satisfied: kneed in C:\Users\s...user\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.8.6)
# Requirement already satisfied: numpy>=1.14.2 in C:\Users\s...user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kneed) (2.3.2)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\s...user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from kneed) (1.16.1)

# %%
from kneed import KneeLocator

# %%
knee = KneeLocator(range(1,21),wcss,curve="convex",direction="decreasing")

# %%
print(knee.elbow)
# Out:
# 4
