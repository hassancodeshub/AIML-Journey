# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("thyroid_dataset.csv")

# %%
df.sample(3)
# Out:
#        Age  Sex  on_thyroxine  query_on_thyroxine  on_antithyroid_medication  \
# 3824  0.66    0             1                   0                          0
# 2546  0.92    0             0                   0                          0
# 219   0.87    0             0                   0                          0
#
#       sick  pregnant  thyroid_surgery  I131_treatment  query_hypothyroid  ...  \
# 3824     0         0                0               0                  0  ...
# 2546     0         0                0               0                  0  ...
# 219      0         0                0               0                  0  ...
#
#       goitre  tumor  hypopituitary  psych       TSH  T3_measured  \
# 3824       0      0              0      0   0.00030         16.0
# 2546       0      0              0      0   0.00014          9.0
# 219        0      0              0      0  14.00000         17.0
#
#       TT4_measured  T4U_measured  FTI_measured  Outlier_label
# ...

# %%
df.shape
# Out:
# (6916, 22)

# %%
X = df.drop("Outlier_label",axis=1)
y = df["Outlier_label"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Isolation Forest :

from sklearn.ensemble import IsolationForest

IF = IsolationForest(
    n_estimators=200,
    contamination='auto',
    random_state=42
)

# %%
labels = IF.fit_predict(X_scaled)

# %%
# PCA :

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
import numpy as np
print(f"Anomaly Count : {np.sum(labels==-1)}")

plt.figure(figsize=(8,6))

sns.scatterplot(x=X_pca[:,0],y=X_pca[:,1],c=labels)
# Out:
# Anomaly Count : 270
# <Axes: >

# %%
# Isolation Forest : (With known contamination)

from sklearn.ensemble import IsolationForest

IF = IsolationForest(
    n_estimators=200,
    contamination=0.036,
    random_state=42
)

labels = IF.fit_predict(X_scaled)

print(f"Anomaly Count : {np.sum(labels==-1)}")

plt.figure(figsize=(8,6))

sns.scatterplot(x=X_pca[:,0],y=X_pca[:,1],c=labels)
# Out:
# Anomaly Count : 249
# <Axes: >
