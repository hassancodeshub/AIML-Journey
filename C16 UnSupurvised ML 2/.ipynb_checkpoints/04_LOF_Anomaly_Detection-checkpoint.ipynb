# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("thyroid_dataset.csv")

# %%
df.sample(3)
# Out:
#        Age  Sex  on_thyroxine  query_on_thyroxine  on_antithyroid_medication  \
# 4646  0.25    0             0                   0                          0
# 5971  0.53    1             1                   0                          0
# 6286  0.77    1             0                   0                          0
#
#       sick  pregnant  thyroid_surgery  I131_treatment  query_hypothyroid  ...  \
# 4646     1         0                0               0                  0  ...
# 5971     0         0                0               0                  0  ...
# 6286     0         0                0               0                  0  ...
#
#       goitre  tumor  hypopituitary  psych     TSH  T3_measured  TT4_measured  \
# 4646       0      0              0      0  0.0014         16.0         78.00
# 5971       0      0              0      0  0.0015         28.0          0.13
# 6286       0      0              0      0  0.0013          5.0         54.00
#
#       T4U_measured  FTI_measured  Outlier_label
# 4646          88.0          89.0              n
# 5971         101.0         128.0              n
# 6286          86.0          62.0              n
#
# [3 rows x 22 columns]

# %%
df.shape
# Out:
# (6916, 22)

# %%
X = df.drop("Outlier_label",axis=1)
y = df["Outlier_label"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Isolation Forest :

from sklearn.neighbors import LocalOutlierFactor

LOF = LocalOutlierFactor(
    contamination=0.036
)

# %%
labels = LOF.fit_predict(X_scaled)

# %%
# PCA :

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
import numpy as np
print(f"Anomaly Count : {np.sum(labels==-1)}")

plt.figure(figsize=(8,6))

sns.scatterplot(x=X_pca[:,0],y=X_pca[:,1],c=labels)
# Out:
# Anomaly Count : 249
# <Axes: >
