# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=data["bmi"],y=data["charges"],hue=data["smoker"])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# Variable Partition :
X = data.drop(columns=["charges"])
Y = data["charges"]

# %%
# Encoding :
X = pd.get_dummies(X, columns=["region"], drop_first=True, dtype=int)

X["sex"] = X["sex"].map({"female": 1, "male": 0})
X["smoker"] = X["smoker"].map({"yes": 1, "no": 0})

X["age_smoker"] = X["age"] * X["smoker"]
X["bmi_smoker"] = X["bmi"] * X["smoker"]

# %%
X
# Out:
#       age  sex     bmi  children  smoker  region_northwest  region_southeast  \
# 0      19    1  27.900         0       1                 0                 0
# 1      18    0  33.770         1       0                 0                 1
# 2      28    0  33.000         3       0                 0                 1
# 3      33    0  22.705         0       0                 1                 0
# 4      32    0  28.880         0       0                 1                 0
# ...   ...  ...     ...       ...     ...               ...               ...
# 1333   50    0  30.970         3       0                 1                 0
# 1334   18    1  31.920         0       0                 0                 0
# 1335   18    1  36.850         0       0                 0                 1
# 1336   21    1  25.800         0       0                 0                 0
# 1337   61    1  29.070         0       1                 1                 0
#
#       region_southwest  age_smoker  bmi_smoker
# 0                    1          19       27.90
# 1                    0           0        0.00
# 2                    0           0        0.00
# 3                    0           0        0.00
# 4                    0           0        0.00
# ...                ...         ...         ...
# 1333                 0           0        0.00
# 1334                 0           0        0.00
# 1335                 0           0        0.00
# 1336                 1           0        0.00
# 1337                 0          61       29.07
#
# [1338 rows x 10 columns]

# %%
# Train - Test - Split : 

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Model Training Phase :
from sklearn.linear_model import LassoCV
a = [0.001, 0.1, 1, 2, 5, 10, 20, 30, 40, 50, 100]
lasso_cv_model = LassoCV(
    alphas=a,
    cv=5,
    max_iter=1000,
    random_state=42
)

lasso_cv_model.fit(X_train, Y_train)
# Out:
# LassoCV(alphas=[0.001, 0.1, 1, 2, 5, 10, 20, 30, 40, 50, 100], cv=5,
#         random_state=42)

# %%
# Making the value prediction :

print("best alpha: ", lasso_cv_model.alpha_)
y_pred = lasso_cv_model.predict(X_test)
# Out:
# best alpha:  0.001

# %%
y_pred
# Out:
# array([11244.90059978,  7419.09546268, 33108.56314007, 10825.70490225,
#        28165.85343431,  6492.31635767,  2795.32365354, 14417.83354245,
#         5686.99898738, 11674.71818244, 20657.63411334,  9146.42228702,
#         5695.47634768, 51922.22671926, 52110.29374917, 46640.13982805,
#        11685.29658629, 43258.62998667, 10134.76616091, 27544.19263391,
#         5590.70961111,  9112.26802402,  1829.44144206,  4568.32135944,
#        12451.66467979, 12838.43441863, 13233.1683341 ,  6449.57391511,
#        11799.9295961 ,  1825.10892897,  9707.98336691, 12978.53929819,
#         3236.118998  ,  7025.38251479,  4125.34903234, 10091.32515432,
#         3262.60158493,  9119.59900771, 26284.76520845, 37686.42549368,
#         4634.26679081,  3702.06925208, 12658.70586842, 12849.09340889,
#         6810.6449285 , 12752.77601579,  4474.36939417,  5198.07859716,
#        41615.56500411,  6338.52575124, 14310.54334662,  2272.59365192,
#         9166.72907954,  2711.78458203, 11905.93655599, 12175.66877205,
.232154284533, 8283.6807), (8318.988508014105, 6338.0756), (9287.375752856911, 7152.6714), (7079.893716304448, 4889.0368), (6599.95285019931, 4846.92015), (12589.611543794643, 11454.0215), (5965.234097621071, 4349.462), (10486.279710489684, 9101.798), (2416.1368996162228, 1391.5287), (32401.171393400684, 28101.33305), (6687.9433863348495, 5152.134), (38390.73954382738, 38511.6283), (59888.16859706853, 44501.3982), (36869.69504268587, 41097.16175), (6399.6322222210965, 4837.5823), (11946.360953933472, 10601.63225), (10199.914471607768, 8310.83915), (12286.865102792113, 11264.541), (15979.116854236365, 15230.32405), (26964.461708982977, 27037.9141), (28565.604590744777, 23401.30575), (7087.9361934161225, 5031.26955), (37711.4940112699, 38282.7495), (8578.14494763015, 6875.961), (27278.789472411503, 19719.6947), (2934.9961073248433, 1880.07), (20673.64066640303, 18765.87545), (8580.200063468288, 6402.29135), (6271.451543371548, 4527.18295), (2324.4373070096754, 1743.214), (8080.110334800542, 5709.1644), (13065.61409598305, 12363.547), (13969.646789112698, 13129.60345), (2391.5024453026563, 1727.54), (9600.246747449391, 7731.4271), (20408.282908107132, 21195.818), (2616.84111150015, 1702.4553), (24348.985383800362, 23244.7902), (1884.5106945667221, 23082.95533), (4726.448020094563, 2927.0647), (14347.74054823184, 13019.16105), (33760.58687462403, 37701.8768), (11947.959968076982, 9778.3472), (2608.643084854806, 1980.07), (13807.420790883192, 30259.99556), (27593.646038823077, 22478.6), (8287.203863579927, 6313.759), (3883.6714687858266, 2789.0574), (8053.603121538856, 5594.8455), (9220.051917232475, 7261.741) ...

# %%
# Evaluation Metrics :

# %%
# Mean Squared Value :

mse = mean_squared_error(Y_test, y_pred)
print(mse)
# Out:
# 20922599.871035974

# %%
# 1] R Squared :

from sklearn.metrics import r2_score
r_square = r2_score(Y_test, y_pred)
# Linear Regression R square value : 0.7811302113434095 
print(f"R square value : {r_square} ")
# Out:
# R square value : 0.8652317499151698

# %%
# 2 Adjusted R Squared :

# No. of rows :
n = X_test.shape[0]
print(X_test.shape[0])

# No. of cols :
p = X_test.shape[1]
print(X_test.shape[1])


# Linear Regression: 
# Adjusted R Square Value :0.7769533069797342

r_adjusted = 1-(((1-r_square)*(n-1))/(n-p-1))

print(f"Adjusted R Square Value :{r_adjusted}")
# Out:
# 268
# 10
# Adjusted R Square Value :0.8599878491336589

# %%
# Finding the best alpha :


alphas = [0.001, 0.1, 1, 2, 5, 10, 20, 30, 40, 50, 100]
mses = []


for a in alphas:
    lasso_model = Lasso(alpha=a)
    lasso_model.fit(X_train, Y_train)
    y_pred = lasso_model.predict(X_test)
    mse = mean_squared_error(Y_test,y_pred)
    print(mse)
    mses.append(mse)

sns.lineplot(x=alphas,y=mses,marker="o")
print(f"Best alpha = ")
# Out:
# 20922599.871035974
# 20921803.69843139
# 20914832.635089148
# 20908106.779954527
# 20890881.000633504
# 20872844.794796687
# 20877828.53237883
# 20937537.13393977
# 21046489.293890774
# 21196929.869608898
# 22423172.68602322
# Best alpha =
