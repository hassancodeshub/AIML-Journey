# %%
import numpy as np

# %%
#Integer,String,Bool,Object,Float

# %%
#Complex Numbers :

cmplx1 = np.array([5+3j,2+4j])
cmplx2 = np.array([1+2j,8+3j])
print(cmplx1,cmplx1.dtype)
print(cmplx2,cmplx2.dtype)
print(cmplx1+cmplx2)
# Out:
# [5.+3.j 2.+4.j] complex128
# [1.+2.j] complex128
# [6.+5.j 3.+6.j]
