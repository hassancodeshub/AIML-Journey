# %%
import numpy as np

# %%
arr=np.array([[1,2],[3,4]])
print(arr)


"""
Normalization  = (arr[val] - mean) / standard deviation
"""


mean = np.mean(arr)
std = np.std(arr)

print(mean)
print(std)

normalization  = (arr-mean)/std
print(normalization)
# Out:
# [[1 2]
#  [3 4]]
# 2.5
# 1.118033988749895
# [[-1.34164079 -0.4472136 ]
#  [ 0.4472136   1.34164079]]
