# %%
import pandas as pd
d = pd.read_csv("raw_data.csv")

# %%
# List of Data Type Column wise :
print(d.dtypes)
# Out:
# id           int64
# name        object
# age        float64
# country     object
# gender      object
# income     float64
# dtype: object

# %%
# Convert into another data - type :
d["id"] = d["id"].astype("float64")
print(d)

d["age"]=d["age"].fillna(0)
d["age"] = d["age"].astype("int64")
# Out:
#       id          name  age country   gender   income
# 0    1.0      John Doe   29     USA     Male  55000.0
# 1    1.0      John Doe   29     USA     Male  55000.0
# 2    2.0    Jane Smith    0  Canada   Female  62000.0
# 3    3.0          Alex    0     USA  Unknown  47000.0
# 4    4.0  Maria Garcia   34   Spain   Female      NaN
# 5    5.0        Li Wei   27   China     Male  51000.0
# 6    6.0           NaN   45   India   Female  73000.0
# 7    7.0    Ahmed Khan   38     NaN     Male  68000.0
# 8    8.0    Rachel Lee   29     USA   Female  62000.0
# 9    9.0   Carlos Ruiz    0  Mexico     Male  45000.0
# 10  10.0   Emily Davis   31     USA      NaN  58000.0

# %%
# Convert into the datae - time format of Pandas :

data = pd.read_csv("globalAirQuality.csv")
print(data.columns)

print(data["timestamp"].dtype)

data["timestamp"]=pd.to_datetime(data["timestamp"])

print(data["timestamp"].dtype)
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')
# object
# datetime64[ns]
