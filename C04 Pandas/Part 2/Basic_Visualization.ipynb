# %%
import pandas as pd
d = pd.read_csv("raw_data.csv")

# %%
d.hist()
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'income'}>, <Axes: >]], dtype=object)

# %%
d.plot(kind = "scatter",x="age",y="income")
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
d.plot(kind = "box",x="age",y="income")
# Out:
# <Axes: >

# %%
d.plot()
# Out:
# <Axes: >

# %%
d.plot(kind = "bar")
# Out:
# <Axes: >
