# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
tips = sns.load_dataset("tips")

# %%
# Like Multiple Data sets in plt : 

sns.barplot(
    data=tips,
    x = "day",
    y = "tip",
    hue = "sex"
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
